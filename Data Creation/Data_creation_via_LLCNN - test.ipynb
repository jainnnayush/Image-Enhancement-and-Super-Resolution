# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytorch-msssim

# %%
import glob
import random
import os
import numpy as np
import argparse
import math
import itertools
import sys

import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid

from torch.utils.data import DataLoader
from torch.autograd import Variable

from matplotlib import pyplot as ply

from pytorch_msssim import ssim, ms_ssim, SSIM, MS_SSIM

# Normalization parameters for pre-trained PyTorch models
mean = np.array([0.485, 0.456, 0.406])
std = np.array([0.229, 0.224, 0.225])

# %%
from drive.MyDrive.ImageSuperResolution  import LLCNN

# %%
class ImageDataset(Dataset):
    def __init__(self, root, shape, transform):
        height, width = shape
        # Transforms for low resolution images and high resolution images
        self.transform = transform

        self.files = sorted(glob.glob(root + "/*.*"))

    def __getitem__(self, index):
        low_path = self.files[index % len(self.files)]
        #high_path = low_path.replace('low','high')
        
        img_low = Image.open(low_path)
        #img_high = Image.open(high_path)
        
        img_low = self.transform(img_low)
        #img_high = self.transform(img_high)
         
        name = low_path[68:]

        return {"low": img_low, "name": name}


    def __len__(self):
        return len(self.files)

# %%
root = '/content/drive/MyDrive/ImageSuperResolution/DatasetBatches/test/low/'
shape = (400//4,400//4)

transform = transforms.Compose(
            [
                transforms.Resize((shape[0], shape[1]), Image.BICUBIC),
                transforms.ToTensor(),
                #transforms.Normalize(mean, std),
            ]
        )
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "

# %%
data = ImageDataset(root, shape, transform)

# %%
data[0]['low'].shape
# Out:
# torch.Size([3, 100, 100])

# %%
data[0]['name']
# Out:
# 'image5000.jpg'

# %%
n = 200
batch_size = 256 #len(data)
channels = 3

CONV_BLOCKS = 5
RESIDUAL = True

# %%
cuda = torch.cuda.is_available()

# %%
model = LLCNN.LLCNN(channels, CONV_BLOCKS, RESIDUAL)

# %%
model.load_state_dict(torch.load("/content/drive/MyDrive/ImageSuperResolution/LLCNN/saved_models/model_"+str(n-1)+".pth"))
# Out:
# <All keys matched successfully>

# %%
if cuda:
    model = model.to('cuda')

# %%
dataloader = DataLoader(
    data,
    batch_size=4,#batch_size,#len(data),
    shuffle=True,
    num_workers=0,
)

# %%
"""dataiter = iter(dataloader)
data_ = dataiter.next()"""
# Out:
# 'dataiter = iter(dataloader)\ndata_ = dataiter.next()'

# %%
data = iter(dataloader)
data.next()['name']
# Out:
# ['image5006.jpg', 'image5114.jpg', 'image5299.jpg', 'image5437.jpg']

# %%
Tensor = torch.cuda.FloatTensor if cuda else torch.Tensor

# %%
os.makedirs("/content/drive/MyDrive/ImageSuperResolution/DatasetBatches/test/LLCNN_generated", exist_ok=True)

# %%
generated_image_root = '/content/drive/MyDrive/ImageSuperResolution/DatasetBatches/test/LLCNN_generated/'
for i, imgs in enumerate(dataloader):
        img_low = Variable(imgs["low"].type(Tensor))
        outputs = model(img_low)
        outputs.detach_
        outputs = outputs.to('cpu')
        for i, img in enumerate(outputs):
            save_image(img, generated_image_root + imgs['name'][i])
